# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import numpy as np
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0     howard springs -12.4970  131.0470     26.95        95
# 1        1  port-aux-francais -49.3500   70.2167      4.37        96
# 2        2             badger  64.8000 -147.5333     -5.00        81
# 3        3             besuki  -7.7338  113.6979     26.29        76
# 4        4        west island -12.1568   96.8225     25.99        94
#
#    Cloudiness  Wind Speed Country        Date
# 0          66        1.32      AU  1730834790
# 1         100        6.76      TF  1730834791
# 2         100        3.60      US  1730834792
# 3          99        1.03      ID  1730834793
# 4         100        7.20      CC  1730834794

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City"
)

# Display the map
humidity_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# I'd like to go somewhere with highs between 55 and 75 F (roughly 13-23 C)
filtered_city_data = city_data_df.loc[(city_data_df['Max Temp']<=23) & (city_data_df['Max Temp']>=13)]

#Fixing Namibia country code
filtered_city_data.loc[filtered_city_data['Country'].isna(), 'Country'] = 'NA'

# Drop any rows with null values
np.where(pd.isnull(filtered_city_data))
np.where(pd.isna(filtered_city_data))
    #We have no missing or null values


# Display sample data
filtered_city_data.head()
# Out:
#     City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 11       11  port elizabeth -33.9180   25.5701     15.16        89
# 13       13    hualien city  23.9769  121.6044     22.40        84
# 15       15          albany  42.6001  -73.9662     22.58        58
# 16       16            lebu -37.6167  -73.6500     13.85        70
# 17       17        waitangi -43.9535 -176.5597     14.34        89
#
#     Cloudiness  Wind Speed Country        Date
# 11          40        2.06      ZA  1730834802
# 13          74        5.25      TW  1730834805
# 15          64        0.89      US  1730834605
# 16         100        3.10      CL  1730834808
# 17          95        0.89      NZ  1730834592

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_city_data[['City', 'Country','Lat','Lng','Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df.head()
# Out:
#               City Country      Lat       Lng  Humidity Hotel Name
# 11  port elizabeth      ZA -33.9180   25.5701        89
# 13    hualien city      TW  23.9769  121.6044        84
# 15          albany      US  42.6001  -73.9662        58
# 16            lebu      CL -37.6167  -73.6500        70
# 17        waitangi      NZ -43.9535 -176.5597        89

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
limit = 1
radius = 5000 #hotels within 5km of the coordinates
params = {
    "limit":limit,
    "categories": f"accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port elizabeth - nearest hotel: Waterford Hotel
# hualien city - nearest hotel: view hoster
# albany - nearest hotel: No hotel found
# lebu - nearest hotel: No hotel found
# waitangi - nearest hotel: Hotel Chathams
# bredasdorp - nearest hotel: Victoria Hotel
# lompoc - nearest hotel: Red Roof Inn Lompoc
# xianning - nearest hotel: No hotel found
# mount isa - nearest hotel: Ibis Styles
# adamstown - nearest hotel: No hotel found
# laguna - nearest hotel: Holiday Inn Express & Suites
# richards bay - nearest hotel: SUN1 Richards Bay
# east london - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# mwene-ditu - nearest hotel: Hôtel KAMAS
# tura - nearest hotel: Hotel Polo Orchid
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# edinburgh of the seven seas - nearest hotel: No hotel found
# upington - nearest hotel: Die Eiland Holiday Ressort
# tshabong - nearest hotel: No hotel found
# port macquarie - nearest hotel: The Observatory
# buka - nearest hotel: No hotel found
# san angelo - nearest hotel: Hilton Hotel
# margaret river - nearest hotel: Margaret River Hotel
# callao - nearest hotel: Casa Ronald
# crane - nearest hotel: No hotel found
# isangel - nearest hotel: Tanna Lodge
# kasama - nearest hotel: No hotel found
# alofi - nearest hotel: No hotel found
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# nova xavantina - nearest hotel: Hotel Morada do Sol
# colares - nearest hotel: Quinta de São Tadeu
# port saint john's - nearest hotel: Outback Inn
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
# al kharijah - nearest hotel: Kharga Hotel
# tippi - nearest hotel: Tepi genet penision
# port alfred - nearest hotel: No hotel found
# ribeira grande - nearest hotel: No hotel found
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# el jadid - nearest hotel: Hotel El Jadida
# westport - nearest hotel: Norwalk Inn and Conference Center
# qal'ah-ye shahr - nearest hotel: No hotel found
# buritis - nearest hotel: No hotel found
# swan view - nearest hotel: No hotel found
# pisco - nearest hotel: La Portada
# malpica - nearest hotel: Pensión Panchito
# mugia - nearest hotel: Solpor do Coído
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# sitia - nearest hotel: Itanos Hotel
# port lincoln - nearest hotel: Boston Hotel
# el hadjira - nearest hotel: No hotel found
# omuta - nearest hotel: ビジネスホテルわらじ家別館
# ingeniero jacobacci - nearest hotel: Gran Hotel Argentino
# naze - nearest hotel: ビジネス旅館畠山
# walvis bay - nearest hotel: Atlantic
# papireddippatti - nearest hotel: No hotel found
# yen vinh - nearest hotel: Mường Thanh Luxury Song Lam Hotel
# namibe - nearest hotel: Nelsal Pensao
# carnarvon - nearest hotel: No hotel found
# lolodorf - nearest hotel: No hotel found
# jiazi - nearest hotel: No hotel found
# yangjiang - nearest hotel: Jinghu Hotel
# grand gaube - nearest hotel: Hotel Lux- Grand Gaube
# saint-francois - nearest hotel: No hotel found
# shahritus - nearest hotel: Marhabo Hotel
# newman - nearest hotel: No hotel found
# lota - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# eastham - nearest hotel: Four Points by Sheraton
# saint-philippe - nearest hotel: Le Baril
# gurupi - nearest hotel: Via Norte
# clodomira - nearest hotel: No hotel found
# penafiel - nearest hotel: No hotel found
# ballito - nearest hotel: The Vineyard On Ballito
# minas de marcona - nearest hotel: No hotel found
# yanykurgan - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# bedesa - nearest hotel: No hotel found
# hasaki - nearest hotel: Choshi Plaza Hotel
# ebolowa - nearest hotel: Hôtel le Relais
# arar - nearest hotel: دار أوتيل Dar Otel
# ha tinh - nearest hotel: Hong Chau Nha Nhgi
# ardmore - nearest hotel: Best Western Plus
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# port pirie - nearest hotel: Ellen Hotel
# cao bang - nearest hotel: SONG HIEN HOTEL
# blythe - nearest hotel: Quality Inn
# springs - nearest hotel: Manhattan Hotel & Action Bar
# kuruman - nearest hotel: Palermo Inn
# polavaram - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# cambria - nearest hotel: Olallieberry Inn
# tukrah - nearest hotel: No hotel found
# tsiombe - nearest hotel: No hotel found
# noosa heads - nearest hotel: Costa Nova Apartments
# prigen - nearest hotel: Royal Trawas Hotel & Cottages
# polignano a mare - nearest hotel: Hotel Covo dei Saraceni
# shimoda - nearest hotel: ホテルウラガ
# sumbawa besar - nearest hotel: Hotel Mekarsari
# az zuwaytinah - nearest hotel: No hotel found
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# luena - nearest hotel: No hotel found
# sabzevar - nearest hotel: مامورسرا مخابرات سبزوار
# hit - nearest hotel: No hotel found
# kerman - nearest hotel: حافظ
# coquimbo - nearest hotel: Hotel Iberia
# pacific grove - nearest hotel: Pacific Grove Inn
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# messaad - nearest hotel: نزل
# praia da vitoria - nearest hotel: Salles
# alexandria - nearest hotel: Smoha Zahran Haus (7th floor)
# horta - nearest hotel: Azoris Faial Garden - Resort Hotel
# jianguang - nearest hotel: No hotel found
# misratah - nearest hotel: الفندق السياحى
# huarmey - nearest hotel: Hostal Santa Rosa
# tralee - nearest hotel: The Ashe Hotel
# sibundoy - nearest hotel: Hotel El Mirador
# luderitz - nearest hotel: Seaview Hotel Zum Sperrgebiet
# christchurch - nearest hotel: Ibis Hotel Christchurch
# moyynkum - nearest hotel: No hotel found
# dar chioukh - nearest hotel: No hotel found
# ulladulla - nearest hotel: Hotel Marlin
# merowe - nearest hotel: Merowe Land
# el granada - nearest hotel: Beach House
# sangkhla buri - nearest hotel: ศรีแดง โฮเต็ล
# gordonvale - nearest hotel: No hotel found
# chania - nearest hotel: Morum
# viana do castelo - nearest hotel: Casa Manuel Espregueira e Oliveira
# ceerigaabo - nearest hotel: Sanaag Hotel
# saint louis - nearest hotel: Frontenac Hilton Hotel
# ghanzi - nearest hotel: Ghanzi farmhouse
#                  City Country      Lat       Lng  Humidity  \
# 11     port elizabeth      ZA -33.9180   25.5701        89
# 13       hualien city      TW  23.9769  121.6044        84
# 15             albany      US  42.6001  -73.9662        58
# 16               lebu      CL -37.6167  -73.6500        70
# 17           waitangi      NZ -43.9535 -176.5597        89
# ..                ...     ...      ...       ...       ...
# 539            chania      GR  35.5122   24.0156        72
# 540  viana do castelo      PT  41.6932   -8.8329        90
# 544        ceerigaabo      SO  10.6162   47.3680        71
# 546       saint louis      US  38.6334  -90.4001        91
# 553            ghanzi      BW -21.5667   21.7833        12
#
#                              Hotel Name
# 11                      Waterford Hotel
# 13                          view hoster
# 15                       No hotel found
# 16                       No hotel found
# 17                       Hotel Chathams
# ..                                  ...
# 539                               Morum
# 540  Casa Manuel Espregueira e Oliveira
# 544                        Sanaag Hotel
# 546              Frontenac Hilton Hotel
# 553                    Ghanzi farmhouse
#
# [131 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
