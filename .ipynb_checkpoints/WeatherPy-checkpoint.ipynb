# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-aux-francais
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | crane
# Processing Record 4 of Set 1 | pisco
# Processing Record 5 of Set 1 | ak'ordat
# Processing Record 6 of Set 1 | zaysan
# Processing Record 7 of Set 1 | jiwani
# Processing Record 8 of Set 1 | stanley
# Processing Record 9 of Set 1 | grytviken
# Processing Record 10 of Set 1 | al ghayzah
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | portland
# Processing Record 13 of Set 1 | kristiansund
# Processing Record 14 of Set 1 | guerrero negro
# Processing Record 15 of Set 1 | conselheiro pena
# Processing Record 16 of Set 1 | thames
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | isafjordur
# Processing Record 19 of Set 1 | arrifes
# Processing Record 20 of Set 1 | luganville
# Processing Record 21 of Set 1 | blackmans bay
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | yangambi
# Processing Record 24 of Set 1 | harper
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | edinburgh of the seven seas
# Processing Record 27 of Set 1 | remire-montjoly
# Processing Record 28 of Set 1 | kodiak
# Processing Record 29 of Set 1 | matola
# Processing Record 30 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | hamilton
# Processing Record 33 of Set 1 | soro
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | roxas
# Processing Record 36 of Set 1 | iskateley
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | qaqortoq
# Processing Record 39 of Set 1 | san antonio de pale
# Processing Record 40 of Set 1 | tazovsky
# Processing Record 41 of Set 1 | wailua homesteads
# Processing Record 42 of Set 1 | lihue
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | turkmenbasy
# Processing Record 45 of Set 1 | beyla
# Processing Record 46 of Set 1 | abu tij
# Processing Record 47 of Set 1 | ilulissat
# Processing Record 48 of Set 1 | san bernardo del viento
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | bonnyville
# Processing Record 0 of Set 2 | altay
# Processing Record 1 of Set 2 | invercargill
# Processing Record 2 of Set 2 | ii
# City not found. Skipping...
# Processing Record 3 of Set 2 | lebu
# Processing Record 4 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 5 of Set 2 | cabo san lucas
# Processing Record 6 of Set 2 | taoudenni
# Processing Record 7 of Set 2 | datong
# Processing Record 8 of Set 2 | puerto natales
# Processing Record 9 of Set 2 | tenenkou
# Processing Record 10 of Set 2 | springfield
# Processing Record 11 of Set 2 | kirs
# Processing Record 12 of Set 2 | callao
# Processing Record 13 of Set 2 | zhengjiatun
# Processing Record 14 of Set 2 | enewetak
# Processing Record 15 of Set 2 | college
# Processing Record 16 of Set 2 | tiksi
# Processing Record 17 of Set 2 | morant bay
# Processing Record 18 of Set 2 | aquiraz
# Processing Record 19 of Set 2 | aracuai
# Processing Record 20 of Set 2 | nikol'sk
# Processing Record 21 of Set 2 | bilibino
# Processing Record 22 of Set 2 | colonia
# Processing Record 23 of Set 2 | salinopolis
# Processing Record 24 of Set 2 | sargatskoye
# Processing Record 25 of Set 2 | afaahiti
# Processing Record 26 of Set 2 | whitehorse
# Processing Record 27 of Set 2 | st. john's
# Processing Record 28 of Set 2 | rongelap
# Processing Record 29 of Set 2 | san jose de jachal
# Processing Record 30 of Set 2 | cargados carajos
# City not found. Skipping...
# Processing Record 31 of Set 2 | werota
# Processing Record 32 of Set 2 | nuku'alofa
# Processing Record 33 of Set 2 | waitangi
# Processing Record 34 of Set 2 | prado
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | hawaiian paradise park
# Processing Record 37 of Set 2 | najran
# Processing Record 38 of Set 2 | arraial do cabo
# Processing Record 39 of Set 2 | shimanovsk
# Processing Record 40 of Set 2 | nagqu
# Processing Record 41 of Set 2 | nianzishan
# Processing Record 42 of Set 2 | yamada
# Processing Record 43 of Set 2 | anadyr
# Processing Record 44 of Set 2 | san ignacio de velasco
# Processing Record 45 of Set 2 | akureyri
# Processing Record 46 of Set 2 | mvurwi
# Processing Record 47 of Set 2 | asmar
# Processing Record 48 of Set 2 | mitu
# Processing Record 49 of Set 2 | port moresby
# Processing Record 0 of Set 3 | margaret river
# Processing Record 1 of Set 3 | hermanus
# Processing Record 2 of Set 3 | rayon
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | at taj
# Processing Record 5 of Set 3 | flin flon
# Processing Record 6 of Set 3 | port mathurin
# Processing Record 7 of Set 3 | lockwood
# Processing Record 8 of Set 3 | jamestown
# Processing Record 9 of Set 3 | mount pearl
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | sainte-anne-des-monts
# Processing Record 13 of Set 3 | ushuaia
# Processing Record 14 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 15 of Set 3 | bang bua thong
# Processing Record 16 of Set 3 | vorgashor
# Processing Record 17 of Set 3 | flying fish cove
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | klaksvik
# Processing Record 20 of Set 3 | siniscola
# Processing Record 21 of Set 3 | isangel
# Processing Record 22 of Set 3 | ginir
# Processing Record 23 of Set 3 | kirensk
# Processing Record 24 of Set 3 | aykhal
# Processing Record 25 of Set 3 | west island
# Processing Record 26 of Set 3 | slave lake
# Processing Record 27 of Set 3 | rio gallegos
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | baharly
# Processing Record 30 of Set 3 | karatas
# Processing Record 31 of Set 3 | fort mcmurray
# Processing Record 32 of Set 3 | waddan
# Processing Record 33 of Set 3 | jayapura
# Processing Record 34 of Set 3 | saint-pierre
# Processing Record 35 of Set 3 | keflavik
# Processing Record 36 of Set 3 | kruisfontein
# Processing Record 37 of Set 3 | charlestown
# Processing Record 38 of Set 3 | southside
# Processing Record 39 of Set 3 | tual
# Processing Record 40 of Set 3 | homer
# Processing Record 41 of Set 3 | thinadhoo
# Processing Record 42 of Set 3 | east london
# Processing Record 43 of Set 3 | fort st. john
# Processing Record 44 of Set 3 | ust-nera
# Processing Record 45 of Set 3 | port saint john's
# Processing Record 46 of Set 3 | longyearbyen
# Processing Record 47 of Set 3 | alotau
# Processing Record 48 of Set 3 | idri
# Processing Record 49 of Set 3 | lazaro cardenas
# Processing Record 0 of Set 4 | lompoc
# Processing Record 1 of Set 4 | rio grande
# Processing Record 2 of Set 4 | rikaze
# Processing Record 3 of Set 4 | coquimbo
# Processing Record 4 of Set 4 | smithers
# Processing Record 5 of Set 4 | chonchi
# Processing Record 6 of Set 4 | gazipasa
# Processing Record 7 of Set 4 | camocim
# Processing Record 8 of Set 4 | cacheu
# Processing Record 9 of Set 4 | bel ombre
# Processing Record 10 of Set 4 | dudinka
# Processing Record 11 of Set 4 | franklin
# Processing Record 12 of Set 4 | romorantin-lanthenay
# Processing Record 13 of Set 4 | imbituba
# Processing Record 14 of Set 4 | bizerte
# Processing Record 15 of Set 4 | salym
# Processing Record 16 of Set 4 | korla
# Processing Record 17 of Set 4 | la ronge
# Processing Record 18 of Set 4 | frederico westphalen
# Processing Record 19 of Set 4 | happy valley-goose bay
# Processing Record 20 of Set 4 | coahuayana de hidalgo
# Processing Record 21 of Set 4 | ribeira grande
# Processing Record 22 of Set 4 | kyaukse
# Processing Record 23 of Set 4 | howard springs
# Processing Record 24 of Set 4 | kingston
# Processing Record 25 of Set 4 | fale old settlement
# Processing Record 26 of Set 4 | shimoda
# Processing Record 27 of Set 4 | kapa'a
# Processing Record 28 of Set 4 | avarua
# Processing Record 29 of Set 4 | oltinko'l
# Processing Record 30 of Set 4 | wad medani
# Processing Record 31 of Set 4 | puerto aysen
# Processing Record 32 of Set 4 | waat
# Processing Record 33 of Set 4 | udachny
# Processing Record 34 of Set 4 | bikenibeu village
# Processing Record 35 of Set 4 | hami
# Processing Record 36 of Set 4 | utrik
# Processing Record 37 of Set 4 | tolanaro
# Processing Record 38 of Set 4 | ba
# City not found. Skipping...
# Processing Record 39 of Set 4 | liman
# Processing Record 40 of Set 4 | klyuchi
# Processing Record 41 of Set 4 | hiratacho
# Processing Record 42 of Set 4 | talnakh
# Processing Record 43 of Set 4 | saint-joseph
# Processing Record 44 of Set 4 | bafq
# Processing Record 45 of Set 4 | oodweyne
# Processing Record 46 of Set 4 | puerto ayora
# Processing Record 47 of Set 4 | labrador city
# Processing Record 48 of Set 4 | jalai nur
# Processing Record 49 of Set 4 | kailua-kona
# Processing Record 0 of Set 5 | fort bragg
# Processing Record 1 of Set 5 | nuuk
# Processing Record 2 of Set 5 | san patricio
# Processing Record 3 of Set 5 | sao joao da barra
# Processing Record 4 of Set 5 | bam
# Processing Record 5 of Set 5 | thunder bay
# Processing Record 6 of Set 5 | mejit
# Processing Record 7 of Set 5 | nar'yan-mar
# Processing Record 8 of Set 5 | ejido benito juarez
# City not found. Skipping...
# Processing Record 9 of Set 5 | nizhnesortymskiy
# Processing Record 10 of Set 5 | port alfred
# Processing Record 11 of Set 5 | spirit lake
# Processing Record 12 of Set 5 | manokwari
# Processing Record 13 of Set 5 | itarantim
# Processing Record 14 of Set 5 | murun-kuren
# Processing Record 15 of Set 5 | quelimane
# Processing Record 16 of Set 5 | hammerfest
# Processing Record 17 of Set 5 | weatherford
# Processing Record 18 of Set 5 | yuzhno-sukhokumsk
# Processing Record 19 of Set 5 | gadzhiyevo
# Processing Record 20 of Set 5 | linda
# Processing Record 21 of Set 5 | buka
# Processing Record 22 of Set 5 | kismayo
# Processing Record 23 of Set 5 | torres
# Processing Record 24 of Set 5 | papatowai
# Processing Record 25 of Set 5 | vetlanda
# Processing Record 26 of Set 5 | sovetskiy
# Processing Record 27 of Set 5 | linxia chengguanzhen
# Processing Record 28 of Set 5 | hadibu
# Processing Record 29 of Set 5 | sao sebastiao
# Processing Record 30 of Set 5 | selfoss
# Processing Record 31 of Set 5 | tongchuanshi
# Processing Record 32 of Set 5 | gourdon
# Processing Record 33 of Set 5 | mamuju
# Processing Record 34 of Set 5 | yunyang
# Processing Record 35 of Set 5 | caluula
# Processing Record 36 of Set 5 | charters towers
# Processing Record 37 of Set 5 | cafayate
# Processing Record 38 of Set 5 | port blair
# Processing Record 39 of Set 5 | yeed
# Processing Record 40 of Set 5 | bunda
# Processing Record 41 of Set 5 | cangucu
# Processing Record 42 of Set 5 | masina
# Processing Record 43 of Set 5 | ras gharib
# City not found. Skipping...
# Processing Record 44 of Set 5 | kosh-agach
# Processing Record 45 of Set 5 | oeiras
# Processing Record 46 of Set 5 | cape canaveral
# Processing Record 47 of Set 5 | badger
# Processing Record 48 of Set 5 | bowen
# Processing Record 49 of Set 5 | tonkino
# Processing Record 0 of Set 6 | huarmey
# Processing Record 1 of Set 6 | chernyshevsk
# Processing Record 2 of Set 6 | vadso
# Processing Record 3 of Set 6 | gemona
# Processing Record 4 of Set 6 | baise city
# Processing Record 5 of Set 6 | lagos
# Processing Record 6 of Set 6 | taulaga
# Processing Record 7 of Set 6 | semnan
# Processing Record 8 of Set 6 | gueltat zemmour
# City not found. Skipping...
# Processing Record 9 of Set 6 | constantia
# Processing Record 10 of Set 6 | tura
# Processing Record 11 of Set 6 | hailin
# Processing Record 12 of Set 6 | beloyarskiy
# Processing Record 13 of Set 6 | vilyuchinsk
# Processing Record 14 of Set 6 | malaya vishera
# Processing Record 15 of Set 6 | bechem
# Processing Record 16 of Set 6 | moyynkum
# Processing Record 17 of Set 6 | kapuskasing
# Processing Record 18 of Set 6 | mount isa
# Processing Record 19 of Set 6 | galle
# Processing Record 20 of Set 6 | pobugskoye
# Processing Record 21 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 22 of Set 6 | uruzgan
# Processing Record 23 of Set 6 | palangkaraya
# Processing Record 24 of Set 6 | pavuluru
# Processing Record 25 of Set 6 | kawthoung
# City not found. Skipping...
# Processing Record 26 of Set 6 | puerto escondido
# Processing Record 27 of Set 6 | al jawf
# Processing Record 28 of Set 6 | vilhena
# Processing Record 29 of Set 6 | leh
# Processing Record 30 of Set 6 | puerto armuelles
# Processing Record 31 of Set 6 | taesal-li
# Processing Record 32 of Set 6 | sisimiut
# Processing Record 33 of Set 6 | trairi
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | salahonda
# Processing Record 36 of Set 6 | mbanza-ngungu
# Processing Record 37 of Set 6 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 6 | las heras
# Processing Record 39 of Set 6 | luderitz
# Processing Record 40 of Set 6 | concepcion
# Processing Record 41 of Set 6 | benguela
# Processing Record 42 of Set 6 | tionk essil
# Processing Record 43 of Set 6 | queenstown
# Processing Record 44 of Set 6 | new norfolk
# Processing Record 45 of Set 6 | kone
# Processing Record 46 of Set 6 | ad dabbah
# Processing Record 47 of Set 6 | san luis de la loma
# Processing Record 48 of Set 6 | gudari
# Processing Record 49 of Set 6 | horta
# Processing Record 0 of Set 7 | rayachoti
# Processing Record 1 of Set 7 | pimentel
# Processing Record 2 of Set 7 | yazoo city
# Processing Record 3 of Set 7 | la gi
# Processing Record 4 of Set 7 | rozdilna
# Processing Record 5 of Set 7 | suva
# Processing Record 6 of Set 7 | huntingburg
# Processing Record 7 of Set 7 | kashgar
# Processing Record 8 of Set 7 | ribadesella
# Processing Record 9 of Set 7 | grande prairie
# Processing Record 10 of Set 7 | tamandare
# Processing Record 11 of Set 7 | la passe
# Processing Record 12 of Set 7 | hancheng
# Processing Record 13 of Set 7 | pokachi
# Processing Record 14 of Set 7 | turochak
# Processing Record 15 of Set 7 | new ulm
# Processing Record 16 of Set 7 | punta arenas
# Processing Record 17 of Set 7 | arafat
# Processing Record 18 of Set 7 | dryden
# Processing Record 19 of Set 7 | mount gambier
# Processing Record 20 of Set 7 | komsomolets
# Processing Record 21 of Set 7 | bonthe
# Processing Record 22 of Set 7 | saldanha
# Processing Record 23 of Set 7 | zeya
# Processing Record 24 of Set 7 | revda
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | gurupi
# Processing Record 27 of Set 7 | urengoy
# Processing Record 28 of Set 7 | luena
# Processing Record 29 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 30 of Set 7 | ronne
# Processing Record 31 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 32 of Set 7 | ciudad lazaro cardenas
# Processing Record 33 of Set 7 | ariquemes
# Processing Record 34 of Set 7 | oamaru
# Processing Record 35 of Set 7 | panama city beach
# Processing Record 36 of Set 7 | kerikeri
# Processing Record 37 of Set 7 | kingaroy
# Processing Record 38 of Set 7 | rouissat
# Processing Record 39 of Set 7 | alofi
# Processing Record 40 of Set 7 | nungwi
# Processing Record 41 of Set 7 | dakhla
# Processing Record 42 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 43 of Set 7 | coromandel
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | rio preto da eva
# Processing Record 46 of Set 7 | dwarka
# Processing Record 47 of Set 7 | touros
# Processing Record 48 of Set 7 | labytnangi
# Processing Record 49 of Set 7 | seosan
# Processing Record 0 of Set 8 | dunedin
# Processing Record 1 of Set 8 | tupaciguara
# Processing Record 2 of Set 8 | bernburg
# Processing Record 3 of Set 8 | salinas
# Processing Record 4 of Set 8 | praia da vitoria
# Processing Record 5 of Set 8 | igarka
# Processing Record 6 of Set 8 | blackwater
# Processing Record 7 of Set 8 | sovetskaya gavan'
# Processing Record 8 of Set 8 | swords
# Processing Record 9 of Set 8 | glace bay
# Processing Record 10 of Set 8 | khao wong
# Processing Record 11 of Set 8 | pecan plantation
# Processing Record 12 of Set 8 | amos
# Processing Record 13 of Set 8 | vila velha
# Processing Record 14 of Set 8 | taunggyi
# Processing Record 15 of Set 8 | mesyagutovo
# Processing Record 16 of Set 8 | hovd
# Processing Record 17 of Set 8 | sarandi del yi
# Processing Record 18 of Set 8 | luninyets
# Processing Record 19 of Set 8 | antofagasta
# Processing Record 20 of Set 8 | merizo village
# Processing Record 21 of Set 8 | codrington
# Processing Record 22 of Set 8 | ilomantsi
# Processing Record 23 of Set 8 | dul'durga
# Processing Record 24 of Set 8 | elmendorf air force base
# City not found. Skipping...
# Processing Record 25 of Set 8 | sao jose da coroa grande
# Processing Record 26 of Set 8 | nova sintra
# Processing Record 27 of Set 8 | uturoa
# Processing Record 28 of Set 8 | palau
# Processing Record 29 of Set 8 | deyang
# Processing Record 30 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 31 of Set 8 | brigantine
# Processing Record 32 of Set 8 | mach
# Processing Record 33 of Set 8 | mitsamiouli
# Processing Record 34 of Set 8 | plain city
# Processing Record 35 of Set 8 | port lincoln
# Processing Record 36 of Set 8 | mugia
# Processing Record 37 of Set 8 | bosa
# Processing Record 38 of Set 8 | humaita
# Processing Record 39 of Set 8 | camrose
# Processing Record 40 of Set 8 | lata
# Processing Record 41 of Set 8 | atafu village
# Processing Record 42 of Set 8 | rehoboth
# Processing Record 43 of Set 8 | mora
# Processing Record 44 of Set 8 | salmon arm
# Processing Record 45 of Set 8 | port douglas
# Processing Record 46 of Set 8 | ola
# Processing Record 47 of Set 8 | malango
# Processing Record 48 of Set 8 | mutuali
# Processing Record 49 of Set 8 | narvik
# Processing Record 0 of Set 9 | fuerte olimpo
# Processing Record 1 of Set 9 | mossel bay
# Processing Record 2 of Set 9 | villa ocampo
# Processing Record 3 of Set 9 | greymouth
# Processing Record 4 of Set 9 | cururupu
# Processing Record 5 of Set 9 | garhi khairo
# Processing Record 6 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 7 of Set 9 | yuzawa
# Processing Record 8 of Set 9 | bay roberts
# Processing Record 9 of Set 9 | mao
# Processing Record 10 of Set 9 | uberaba
# Processing Record 11 of Set 9 | midland
# Processing Record 12 of Set 9 | barcelos
# Processing Record 13 of Set 9 | gurjaani
# Processing Record 14 of Set 9 | ridgecrest
# Processing Record 15 of Set 9 | cleveland
# Processing Record 16 of Set 9 | pyhajarvi
# Processing Record 17 of Set 9 | plyeshchanitsy
# Processing Record 18 of Set 9 | bermeo
# Processing Record 19 of Set 9 | tarrafal de sao nicolau
# Processing Record 20 of Set 9 | trinidad
# Processing Record 21 of Set 9 | quellon
# Processing Record 22 of Set 9 | westerland
# Processing Record 23 of Set 9 | tostado
# Processing Record 24 of Set 9 | sirte
# Processing Record 25 of Set 9 | khabarovsk
# Processing Record 26 of Set 9 | haiku-pauwela
# Processing Record 27 of Set 9 | mata-utu
# Processing Record 28 of Set 9 | guamal
# Processing Record 29 of Set 9 | langepas
# Processing Record 30 of Set 9 | evans
# Processing Record 31 of Set 9 | yaren
# Processing Record 32 of Set 9 | al bayda'
# Processing Record 33 of Set 9 | neryungri
# Processing Record 34 of Set 9 | isiro
# Processing Record 35 of Set 9 | hulyaypole
# Processing Record 36 of Set 9 | kiama
# Processing Record 37 of Set 9 | lanxi
# Processing Record 38 of Set 9 | kandahar
# Processing Record 39 of Set 9 | monrovia
# Processing Record 40 of Set 9 | mar del plata
# Processing Record 41 of Set 9 | traverse city
# Processing Record 42 of Set 9 | saynshand
# Processing Record 43 of Set 9 | wotje
# Processing Record 44 of Set 9 | geraldton
# Processing Record 45 of Set 9 | cestos city
# Processing Record 46 of Set 9 | hotan
# Processing Record 47 of Set 9 | grand baie
# Processing Record 48 of Set 9 | maceio
# Processing Record 49 of Set 9 | ouesso
# Processing Record 0 of Set 10 | sabzevar
# Processing Record 1 of Set 10 | lubuklinggau
# Processing Record 2 of Set 10 | nantucket
# Processing Record 3 of Set 10 | warren
# Processing Record 4 of Set 10 | levuka
# Processing Record 5 of Set 10 | aur
# Processing Record 6 of Set 10 | tsiombe
# Processing Record 7 of Set 10 | nikolayevsk-on-amure
# Processing Record 8 of Set 10 | sochi
# Processing Record 9 of Set 10 | yeppoon
# Processing Record 10 of Set 10 | newman
# Processing Record 11 of Set 10 | san leone mose
# City not found. Skipping...
# Processing Record 12 of Set 10 | aldan
# Processing Record 13 of Set 10 | copiapo
# Processing Record 14 of Set 10 | chivhu
# Processing Record 15 of Set 10 | kiunga
# Processing Record 16 of Set 10 | kittila
# Processing Record 17 of Set 10 | kimbe
# Processing Record 18 of Set 10 | mundri
# Processing Record 19 of Set 10 | aasiaat
# Processing Record 20 of Set 10 | vernon
# Processing Record 21 of Set 10 | manacapuru
# Processing Record 22 of Set 10 | chany
# Processing Record 23 of Set 10 | padra
# Processing Record 24 of Set 10 | ghadamis
# Processing Record 25 of Set 10 | suchiapa
# Processing Record 26 of Set 10 | watford city
# Processing Record 27 of Set 10 | chicoana
# Processing Record 28 of Set 10 | zhangatas
# Processing Record 29 of Set 10 | nadur
# Processing Record 30 of Set 10 | gorontalo
# Processing Record 31 of Set 10 | prince rupert
# Processing Record 32 of Set 10 | llerena
# Processing Record 33 of Set 10 | tralee
# Processing Record 34 of Set 10 | bakanas
# Processing Record 35 of Set 10 | khovd
# Processing Record 36 of Set 10 | quesnel
# Processing Record 37 of Set 10 | howrah
# Processing Record 38 of Set 10 | puerto baquerizo moreno
# Processing Record 39 of Set 10 | nampula
# Processing Record 40 of Set 10 | grand gaube
# Processing Record 41 of Set 10 | motueka
# Processing Record 42 of Set 10 | darwin
# Processing Record 43 of Set 10 | susuman
# Processing Record 44 of Set 10 | churapcha
# Processing Record 45 of Set 10 | mariental
# Processing Record 46 of Set 10 | chibougamau
# Processing Record 47 of Set 10 | saipan
# Processing Record 48 of Set 10 | orhei
# Processing Record 49 of Set 10 | mmabatho
# Processing Record 0 of Set 11 | ghanzi
# Processing Record 1 of Set 11 | beau vallon
# Processing Record 2 of Set 11 | fada
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | port-vila
# Processing Record 5 of Set 11 | ambovombe
# Processing Record 6 of Set 11 | punta del este
# Processing Record 7 of Set 11 | sinop
# Processing Record 8 of Set 11 | usinsk
# Processing Record 9 of Set 11 | salto
# Processing Record 10 of Set 11 | we
# City not found. Skipping...
# Processing Record 11 of Set 11 | severo-yeniseyskiy
# Processing Record 12 of Set 11 | ebon
# Processing Record 13 of Set 11 | mikuni
# Processing Record 14 of Set 11 | sorong
# Processing Record 15 of Set 11 | raja
# Processing Record 16 of Set 11 | chokwe
# Processing Record 17 of Set 11 | katsuren-haebaru
# Processing Record 18 of Set 11 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 19 of Set 11 | cannonvale
# Processing Record 20 of Set 11 | berbera
# Processing Record 21 of Set 11 | holualoa
# Processing Record 22 of Set 11 | miri
# Processing Record 23 of Set 11 | grand falls-windsor
# Processing Record 24 of Set 11 | novoukrayinka
# Processing Record 25 of Set 11 | brisas de zicatela
# Processing Record 26 of Set 11 | nova vicosa
# Processing Record 27 of Set 11 | minas de marcona
# Processing Record 28 of Set 11 | grajewo
# Processing Record 29 of Set 11 | xai-xai
# Processing Record 30 of Set 11 | camarinas
# Processing Record 31 of Set 11 | koster
# Processing Record 32 of Set 11 | ixtapa
# Processing Record 33 of Set 11 | tarawa
# Processing Record 34 of Set 11 | galliano
# Processing Record 35 of Set 11 | kapit
# Processing Record 36 of Set 11 | dera ghazi khan
# Processing Record 37 of Set 11 | northam
# Processing Record 38 of Set 11 | ilhabela
# Processing Record 39 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 40 of Set 11 | thandla
# Processing Record 41 of Set 11 | sinabang
# Processing Record 42 of Set 11 | arkhangel'sk
# Processing Record 43 of Set 11 | sakakah
# Processing Record 44 of Set 11 | vilyuysk
# Processing Record 45 of Set 11 | wum
# Processing Record 46 of Set 11 | puducherry
# Processing Record 47 of Set 11 | riyadh
# Processing Record 48 of Set 11 | takamaka
# City not found. Skipping...
# Processing Record 49 of Set 11 | maintirano
# Processing Record 0 of Set 12 | yuzhno-kurilsk
# Processing Record 1 of Set 12 | salalah
# Processing Record 2 of Set 12 | swift current
# Processing Record 3 of Set 12 | acarau
# Processing Record 4 of Set 12 | shenjiamen
# Processing Record 5 of Set 12 | timizart
# Processing Record 6 of Set 12 | covasna
# Processing Record 7 of Set 12 | dolores
# Processing Record 8 of Set 12 | papao
# Processing Record 9 of Set 12 | chu
# Processing Record 10 of Set 12 | corumba
# Processing Record 11 of Set 12 | tieli
# Processing Record 12 of Set 12 | oxapampa
# Processing Record 13 of Set 12 | polyarnyy
# Processing Record 14 of Set 12 | newcastle west
# Processing Record 15 of Set 12 | ciudad guayana
# Processing Record 16 of Set 12 | santiago
# Processing Record 17 of Set 12 | isyangulovo
# Processing Record 18 of Set 12 | muhos
# Processing Record 19 of Set 12 | antipino
# Processing Record 20 of Set 12 | vol'sk
# Processing Record 21 of Set 12 | toliara
# Processing Record 22 of Set 12 | garachico
# Processing Record 23 of Set 12 | kariong
# Processing Record 24 of Set 12 | pyongyang
# Processing Record 25 of Set 12 | ghat
# Processing Record 26 of Set 12 | kenai
# Processing Record 27 of Set 12 | ponta delgada
# Processing Record 28 of Set 12 | brookings
# Processing Record 29 of Set 12 | bandarbeyla
# Processing Record 30 of Set 12 | bocaiuva
# Processing Record 31 of Set 12 | sao vicente
# Processing Record 32 of Set 12 | ta`u
# Processing Record 33 of Set 12 | clinton
# Processing Record 34 of Set 12 | kununurra
# Processing Record 35 of Set 12 | sulphur
# Processing Record 36 of Set 12 | mitchell
# Processing Record 37 of Set 12 | hasaki
# Processing Record 38 of Set 12 | la punta
# Processing Record 39 of Set 12 | shubarshi
# Processing Record 40 of Set 12 | ban nong wua so
# Processing Record 41 of Set 12 | mount darwin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          570
# Lat           570
# Lng           570
# Max Temp      570
# Humidity      570
# Cloudiness    570
# Wind Speed    570
# Country       570
# Date          570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  port-aux-francais -49.3500   70.2167      4.71        88         100
# 1        yellowknife  62.4560 -114.3525     -5.71        93          75
# 2              crane  31.3974 -102.3501     12.16        56          64
# 3              pisco -13.7000  -76.2167     18.03        88         100
# 4           ak'ordat  15.5486   37.8867     35.46        21           0
#
#    Wind Speed Country        Date
# 0        9.61      TF  1730985591
# 1        6.69      CA  1730985592
# 2        6.45      US  1730985593
# 3        4.63      PE  1730985594
# 4        2.99      ER  1730985595

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.71        88         100
# 1              yellowknife  62.4560 -114.3525     -5.71        93          75
# 2                    crane  31.3974 -102.3501     12.16        56          64
# 3                    pisco -13.7000  -76.2167     18.03        88         100
# 4                 ak'ordat  15.5486   37.8867     35.46        21           0
#
#          Wind Speed Country        Date
# City_ID
# 0              9.61      TF  1730985591
# 1              6.69      CA  1730985592
# 2              6.45      US  1730985593
# 3              4.63      PE  1730985594
# 4              2.99      ER  1730985595

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=.75, edgecolors='black')

current_date = datetime.date.today()

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature - {current_date}") 
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ### Latitude refers to a location's position north or south of the equator, measured in degrees, while temperature indicates how hot or cold a place is, and is directly influenced by latitude; generally, locations closer to the equator (lower latitudes) experience warmer temperatures, while those closer to the poles (higher latitudes) have colder temperatures due to the angle at which sunlight hits the Earth at different latitudes.

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ### Humidity and latitude are not strongly correlated, but there are some patterns that can be observed:
# Specific humidity
# The amount of water vapor in the air is highest in the tropics and decreases as you move toward the poles. In fact, the air in the driest desert regions (around 30° N or S latitude) contains more water vapor than temperate regions farther north.

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ### There is little to no correlation between latitude and cloudiness. Latitude is a measurement of a location's north or south position on Earth, while cloudiness is the amount of clouds covering the sky:
# ### Latitude
# ### A coordinate that measures a location's north-south position on Earth. Latitude lines run parallel to the equator, starting at 0° latitude at the equator and increasing to 90° at the North and South poles.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linreg_plot(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    f, ax = plt.subplots()
    ax.scatter(x,y)
    ax.plot(x, regress_values, 'red')
    
    return ax, line_eq, rvalue
    
ax, line_eq, rvalue =linreg_plot(city_data_df['Lat'], city_data_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(-30,12),fontsize=15,color="red")
plt.title(f"City Latitude vs. Wind Speed - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.02722924055400314

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        yellowknife  62.4560 -114.3525     -5.71        93          75
# 2              crane  31.3974 -102.3501     12.16        56          64
# 4           ak'ordat  15.5486   37.8867     35.46        21           0
# 5             zaysan  47.4667   84.8667      2.12        60          86
# 6             jiwani  25.0500   61.7417     27.91        75           0
#
#          Wind Speed Country        Date
# City_ID
# 1              6.69      CA  1730985592
# 2              6.45      US  1730985593
# 4              2.99      ER  1730985595
# 5              1.83      KZ  1730985597
# 6              6.94      PK  1730985598

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        port-aux-francais -49.3500   70.2167      4.71        88         100
# 3                    pisco -13.7000  -76.2167     18.03        88         100
# 8                grytviken -54.2811  -36.5092      0.44        87          42
# 14        conselheiro pena -19.1722  -41.4722     25.54        72         100
# 15                  thames -37.1333  175.5333     12.55        95           0
#
#          Wind Speed Country        Date
# City_ID
# 0              9.61      TF  1730985591
# 3              4.63      PE  1730985594
# 8              8.55      GS  1730985600
# 14             1.68      BR  1730985606
# 15             0.26      NZ  1730985607

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
ax.plot()
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Latitude vs. Max Temp, Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Temp (C)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: -0.8274120620859209

# %% [markdown]
# ### A "temperature vs. latitude linear regression" refers to a statistical analysis where the dependent variable is temperature and the independent variable is latitude, using a linear regression model to identify the trend of decreasing temperature as latitude increases, meaning generally, the further away from the equator (higher latitude), the colder the temperature will be; this is because of the angle at which sunlight hits the Earth at different latitudes.

# %%
# Linear regression on Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
ax.plot()
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.title('Latitude vs. Max Temp, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temp (C)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.6998929774341386

# %% [markdown]
# ## Discussion about the linear relationship:
# ### The relationship between latitude and temperature is much stronger in the northern than southern hemishpere, as seen in the tightness of the scatterplot points and will as the R squared values. However the trend is the same for both; the further from the equator, the colder the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
ax.plot()
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.title('Latitude vs. Humidity, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.30231425316111066

# %% [markdown]
# ### The correlation between humidity and latitude is generally weak and negative for both the northern and southern hemispheres. This means that humidity is fairly evenly distributed across cities in both hemispheres, regardless of their distance from the equator. However, there is some correlation at higher latitudes in the northern hemisphere.

# %%
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
ax.plot()
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.title('City Latitude vs. Humidity, southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.24403180466691043

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and humidity appears stronger in the northern hemisphere based on the R value, but I'm not convinenced a linear regression is the best way to model this.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
ax.plot()
plt.annotate(line_eq,(50,15),fontsize=15,color="red")
plt.title('Latitude vs. Cloudiness, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloundiness (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.2870003388338522

# %%
# Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
ax.plot()
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.title('City Latitude vs. Cloudiness, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloundiness (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.13634051058194796

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and cloud cover is not very strong, but it is surprisingly similar for both hemishperes. The regressions indicate a one degree latitude change is related to roughly 0.5% change in cloud cover on average.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(5,12),fontsize=15,color="red")
plt.title('City Latitude vs. Wind Spped, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.1443267248508013

# %%
# Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(-55,10.5),fontsize=15,color="red")
plt.title('City Latitude vs. Wind Spped, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: -0.10008544312626871

# %% [markdown]
# **Discussion about the linear relationship:**
# ## Wind speed and latitude
# Wind speeds are generally lower near the equator and faster in mid-latitudes. For example, the average wind speed in the interiors of South America and Africa near the equator is about 2 meters per second (5 miles per hour), while in the Roaring Forties it's about 11 meters per second (25 miles per hour).
# There is no (linear) relationship between latitude and wind speed. For both hemisphere the slope coefficients and r-values are near zero.
