# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
#pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | papatowai
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | puquio
# Processing Record 6 of Set 1 | grytviken
# Processing Record 7 of Set 1 | port elizabeth
# Processing Record 8 of Set 1 | margaret river
# Processing Record 9 of Set 1 | st. john's
# Processing Record 10 of Set 1 | invercargill
# Processing Record 11 of Set 1 | chinde
# Processing Record 12 of Set 1 | sanctuary point
# Processing Record 13 of Set 1 | arkhipo-osipovka
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | avarua
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | port-aux-francais
# Processing Record 18 of Set 1 | belyy yar
# Processing Record 19 of Set 1 | eruh
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | kingston
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | lebu
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | anloga
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | nemuro
# Processing Record 28 of Set 1 | k'olito
# Processing Record 29 of Set 1 | port moresby
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | shimoda
# Processing Record 33 of Set 1 | ostersund
# Processing Record 34 of Set 1 | stanley
# Processing Record 35 of Set 1 | blackmans bay
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | vikulovo
# Processing Record 38 of Set 1 | trinity beach
# Processing Record 39 of Set 1 | n'zeto
# Processing Record 40 of Set 1 | ambon
# Processing Record 41 of Set 1 | ayora
# Processing Record 42 of Set 1 | souillac
# Processing Record 43 of Set 1 | kodiak
# Processing Record 44 of Set 1 | san pedro pochutla
# Processing Record 45 of Set 1 | edinburgh of the seven seas
# Processing Record 46 of Set 1 | antsiranana
# Processing Record 47 of Set 1 | yukhnov
# Processing Record 48 of Set 1 | bilibino
# Processing Record 49 of Set 1 | isafjordur
# Processing Record 50 of Set 1 | aasiaat
# Processing Record 0 of Set 2 | tshikapa
# Processing Record 1 of Set 2 | toliara
# Processing Record 2 of Set 2 | puerto natales
# Processing Record 3 of Set 2 | port lincoln
# Processing Record 4 of Set 2 | udachny
# Processing Record 5 of Set 2 | kangding
# Processing Record 6 of Set 2 | santa cruz do capibaribe
# Processing Record 7 of Set 2 | vorkuta
# Processing Record 8 of Set 2 | broken hill
# Processing Record 9 of Set 2 | west island
# Processing Record 10 of Set 2 | shilovo
# Processing Record 11 of Set 2 | port mathurin
# Processing Record 12 of Set 2 | dudinka
# Processing Record 13 of Set 2 | colac
# Processing Record 14 of Set 2 | forster
# Processing Record 15 of Set 2 | qamdo
# Processing Record 16 of Set 2 | red hill
# Processing Record 17 of Set 2 | marsh harbour
# Processing Record 18 of Set 2 | pisco
# Processing Record 19 of Set 2 | mocimboa
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | wailua homesteads
# Processing Record 22 of Set 2 | galliano
# Processing Record 23 of Set 2 | sosnytsya
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | tolanaro
# Processing Record 26 of Set 2 | yinchuan
# Processing Record 27 of Set 2 | chandler
# Processing Record 28 of Set 2 | khandyga
# Processing Record 29 of Set 2 | port douglas
# Processing Record 30 of Set 2 | berezovo
# Processing Record 31 of Set 2 | nar'yan-mar
# Processing Record 32 of Set 2 | navia
# Processing Record 33 of Set 2 | waitangi
# Processing Record 34 of Set 2 | ushuaia
# Processing Record 35 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 36 of Set 2 | ancud
# Processing Record 37 of Set 2 | pokrovsk
# Processing Record 38 of Set 2 | filadelfia
# Processing Record 39 of Set 2 | talnakh
# Processing Record 40 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 41 of Set 2 | iqaluit
# Processing Record 42 of Set 2 | saipan
# Processing Record 43 of Set 2 | taoudenni
# Processing Record 44 of Set 2 | siwa oasis
# Processing Record 45 of Set 2 | jiangyou
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | sai buri
# Processing Record 48 of Set 2 | loreto
# Processing Record 49 of Set 2 | mach
# Processing Record 0 of Set 3 | enewetak
# Processing Record 1 of Set 3 | trancas
# Processing Record 2 of Set 3 | dewa
# Processing Record 3 of Set 3 | chandbali
# Processing Record 4 of Set 3 | hoxtolgay
# City not found. Skipping...
# Processing Record 5 of Set 3 | qaqortoq
# Processing Record 6 of Set 3 | tire
# Processing Record 7 of Set 3 | dubrowna
# Processing Record 8 of Set 3 | brookings
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | kerikeri
# Processing Record 11 of Set 3 | bamboo flat
# Processing Record 12 of Set 3 | argo
# Processing Record 13 of Set 3 | kavaratti
# Processing Record 14 of Set 3 | bafra
# Processing Record 15 of Set 3 | iskateley
# Processing Record 16 of Set 3 | northam
# Processing Record 17 of Set 3 | hawaiian paradise park
# Processing Record 18 of Set 3 | susuman
# Processing Record 19 of Set 3 | kiffa
# Processing Record 20 of Set 3 | zapolyarnyy
# Processing Record 21 of Set 3 | cabo san lucas
# Processing Record 22 of Set 3 | thompson
# Processing Record 23 of Set 3 | sogndal
# Processing Record 24 of Set 3 | whitehorse
# Processing Record 25 of Set 3 | mount pearl
# Processing Record 26 of Set 3 | mersa matruh
# Processing Record 27 of Set 3 | cromwell
# Processing Record 28 of Set 3 | okakarara
# Processing Record 29 of Set 3 | albany
# Processing Record 30 of Set 3 | brazzaville
# Processing Record 31 of Set 3 | selfoss
# Processing Record 32 of Set 3 | humaita
# Processing Record 33 of Set 3 | praia da vitoria
# Processing Record 34 of Set 3 | hemsby
# Processing Record 35 of Set 3 | bubaque
# Processing Record 36 of Set 3 | ulaangom
# Processing Record 37 of Set 3 | nantucket
# Processing Record 38 of Set 3 | egilsstadir
# Processing Record 39 of Set 3 | fuglafjordur
# Processing Record 40 of Set 3 | la leonesa
# Processing Record 41 of Set 3 | nyahururu
# Processing Record 42 of Set 3 | sao gabriel da cachoeira
# Processing Record 43 of Set 3 | uturoa
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | utrik
# Processing Record 46 of Set 3 | ketchikan
# Processing Record 47 of Set 3 | ormara
# Processing Record 48 of Set 3 | puerto baquerizo moreno
# Processing Record 49 of Set 3 | alma
# Processing Record 0 of Set 4 | gardabani
# Processing Record 1 of Set 4 | maturin
# Processing Record 2 of Set 4 | glace bay
# Processing Record 3 of Set 4 | chonchi
# Processing Record 4 of Set 4 | santa ana
# Processing Record 5 of Set 4 | keflavik
# Processing Record 6 of Set 4 | gilleleje
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | katsuura
# Processing Record 9 of Set 4 | rakops
# Processing Record 10 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 11 of Set 4 | atafu village
# Processing Record 12 of Set 4 | ust-nera
# Processing Record 13 of Set 4 | vadso
# Processing Record 14 of Set 4 | anadyr
# Processing Record 15 of Set 4 | taveta
# Processing Record 16 of Set 4 | greenville
# Processing Record 17 of Set 4 | taro
# Processing Record 18 of Set 4 | axim
# Processing Record 19 of Set 4 | raiwind
# Processing Record 20 of Set 4 | taroa
# Processing Record 21 of Set 4 | new glasgow
# Processing Record 22 of Set 4 | mermoz boabab
# Processing Record 23 of Set 4 | sisimiut
# Processing Record 24 of Set 4 | choibalsan
# Processing Record 25 of Set 4 | sterlibashevo
# Processing Record 26 of Set 4 | guiria
# City not found. Skipping...
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | sovata
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | machiques
# Processing Record 31 of Set 4 | lethem
# Processing Record 32 of Set 4 | grazzanise
# Processing Record 33 of Set 4 | madang
# Processing Record 34 of Set 4 | broome
# Processing Record 35 of Set 4 | urazovo
# Processing Record 36 of Set 4 | flying fish cove
# Processing Record 37 of Set 4 | olinda
# Processing Record 38 of Set 4 | tadine
# Processing Record 39 of Set 4 | punta arenas
# Processing Record 40 of Set 4 | suva
# Processing Record 41 of Set 4 | kormilovka
# Processing Record 42 of Set 4 | la sarre
# Processing Record 43 of Set 4 | praya
# Processing Record 44 of Set 4 | san salvador
# Processing Record 45 of Set 4 | ilomantsi
# Processing Record 46 of Set 4 | codrington
# Processing Record 47 of Set 4 | berezivka
# Processing Record 48 of Set 4 | las tejerias
# Processing Record 49 of Set 4 | buka
# Processing Record 0 of Set 5 | yarrawonga
# Processing Record 1 of Set 5 | murashi
# Processing Record 2 of Set 5 | ploudalmezeau
# Processing Record 3 of Set 5 | gabu
# Processing Record 4 of Set 5 | nova sintra
# Processing Record 5 of Set 5 | tolstoy-yurt
# Processing Record 6 of Set 5 | ixtapa
# Processing Record 7 of Set 5 | mejit
# Processing Record 8 of Set 5 | mata-utu
# Processing Record 9 of Set 5 | nova xavantina
# Processing Record 10 of Set 5 | holualoa
# Processing Record 11 of Set 5 | boende
# Processing Record 12 of Set 5 | huangpi
# Processing Record 13 of Set 5 | mana
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | ndele
# Processing Record 16 of Set 5 | vilyuysk
# Processing Record 17 of Set 5 | paripiranga
# Processing Record 18 of Set 5 | usogorsk
# Processing Record 19 of Set 5 | sitka
# Processing Record 20 of Set 5 | castanos
# Processing Record 21 of Set 5 | tazovsky
# Processing Record 22 of Set 5 | villefontaine
# Processing Record 23 of Set 5 | timbuktu
# Processing Record 24 of Set 5 | labrador city
# Processing Record 25 of Set 5 | kapuskasing
# Processing Record 26 of Set 5 | yershov
# Processing Record 27 of Set 5 | polyarnyy
# Processing Record 28 of Set 5 | cao bang
# Processing Record 29 of Set 5 | am djarass
# City not found. Skipping...
# Processing Record 30 of Set 5 | luba
# Processing Record 31 of Set 5 | dompu
# Processing Record 32 of Set 5 | lata
# Processing Record 33 of Set 5 | salahonda
# Processing Record 34 of Set 5 | saudarkrokur
# Processing Record 35 of Set 5 | island harbour
# Processing Record 36 of Set 5 | cabedelo
# Processing Record 37 of Set 5 | magdagachi
# Processing Record 38 of Set 5 | oblivskaya
# Processing Record 39 of Set 5 | san luis de la loma
# Processing Record 40 of Set 5 | usinsk
# Processing Record 41 of Set 5 | sidi ifni
# Processing Record 42 of Set 5 | sanming
# Processing Record 43 of Set 5 | chernogorsk
# Processing Record 44 of Set 5 | dingwall
# Processing Record 45 of Set 5 | esmeraldas
# Processing Record 46 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 47 of Set 5 | zaragoza
# Processing Record 48 of Set 5 | chegdomyn
# Processing Record 49 of Set 5 | ponta delgada
# Processing Record 0 of Set 6 | andalgala
# Processing Record 1 of Set 6 | hinatuan
# Processing Record 2 of Set 6 | flin flon
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | georgetown
# Processing Record 5 of Set 6 | saint-pierre
# Processing Record 6 of Set 6 | bafata
# Processing Record 7 of Set 6 | haiku-pauwela
# Processing Record 8 of Set 6 | ouidah
# Processing Record 9 of Set 6 | harper
# Processing Record 10 of Set 6 | zaozersk
# Processing Record 11 of Set 6 | greymouth
# Processing Record 12 of Set 6 | sandnessjoen
# Processing Record 13 of Set 6 | hamilton
# Processing Record 14 of Set 6 | tumbes
# Processing Record 15 of Set 6 | tomatlan
# Processing Record 16 of Set 6 | ulladulla
# Processing Record 17 of Set 6 | west bay
# Processing Record 18 of Set 6 | kashgar
# Processing Record 19 of Set 6 | khor
# Processing Record 20 of Set 6 | la ronge
# Processing Record 21 of Set 6 | leiyang
# Processing Record 22 of Set 6 | nagqu
# Processing Record 23 of Set 6 | salta
# Processing Record 24 of Set 6 | oshawa
# Processing Record 25 of Set 6 | tenno
# Processing Record 26 of Set 6 | brak
# Processing Record 27 of Set 6 | san juan de los morros
# Processing Record 28 of Set 6 | pont rouge
# Processing Record 29 of Set 6 | colby
# Processing Record 30 of Set 6 | puerto deseado
# Processing Record 31 of Set 6 | chui
# Processing Record 32 of Set 6 | veraval
# Processing Record 33 of Set 6 | jawhar
# Processing Record 34 of Set 6 | albesti
# Processing Record 35 of Set 6 | arraial do cabo
# Processing Record 36 of Set 6 | agapovka
# Processing Record 37 of Set 6 | natal
# Processing Record 38 of Set 6 | masina
# Processing Record 39 of Set 6 | kristiansund
# Processing Record 40 of Set 6 | rionero in vulture
# Processing Record 41 of Set 6 | nogliki
# Processing Record 42 of Set 6 | port alfred
# Processing Record 43 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 44 of Set 6 | aras-asan
# Processing Record 45 of Set 6 | palkonda
# Processing Record 46 of Set 6 | ola
# Processing Record 47 of Set 6 | thunder bay
# Processing Record 48 of Set 6 | conceicao do araguaia
# Processing Record 49 of Set 6 | gilford
# Processing Record 0 of Set 7 | funafuti
# Processing Record 1 of Set 7 | revda
# Processing Record 2 of Set 7 | illizi
# Processing Record 3 of Set 7 | ajuchitlan del progreso
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | qarqaraly
# Processing Record 6 of Set 7 | newman
# Processing Record 7 of Set 7 | vettur
# City not found. Skipping...
# Processing Record 8 of Set 7 | cockburn town
# Processing Record 9 of Set 7 | diego de almagro
# Processing Record 10 of Set 7 | vorgashor
# Processing Record 11 of Set 7 | laguna
# Processing Record 12 of Set 7 | gisborne
# Processing Record 13 of Set 7 | porto novo
# Processing Record 14 of Set 7 | 'ohonua
# City not found. Skipping...
# Processing Record 15 of Set 7 | champerico
# Processing Record 16 of Set 7 | mossel bay
# Processing Record 17 of Set 7 | ulsteinvik
# Processing Record 18 of Set 7 | luanda
# Processing Record 19 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 20 of Set 7 | san antonio de pale
# Processing Record 21 of Set 7 | mugia
# Processing Record 22 of Set 7 | saldanha
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | arteche
# Processing Record 25 of Set 7 | lihue
# Processing Record 26 of Set 7 | dalnegorsk
# Processing Record 27 of Set 7 | stephenville
# Processing Record 28 of Set 7 | bay roberts
# Processing Record 29 of Set 7 | mount isa
# Processing Record 30 of Set 7 | san pedro
# Processing Record 31 of Set 7 | port-vila
# Processing Record 32 of Set 7 | mocorito
# Processing Record 33 of Set 7 | kruisfontein
# Processing Record 34 of Set 7 | urangan
# Processing Record 35 of Set 7 | fort mcmurray
# Processing Record 36 of Set 7 | tranby
# Processing Record 37 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 38 of Set 7 | fuvahmulah
# City not found. Skipping...
# Processing Record 39 of Set 7 | bardai
# Processing Record 40 of Set 7 | sambava
# Processing Record 41 of Set 7 | banyuwangi
# Processing Record 42 of Set 7 | baluntaicun
# City not found. Skipping...
# Processing Record 43 of Set 7 | road town
# Processing Record 44 of Set 7 | wagar
# Processing Record 45 of Set 7 | lagos
# Processing Record 46 of Set 7 | mulayjah
# Processing Record 47 of Set 7 | svencionys
# Processing Record 48 of Set 7 | badger
# Processing Record 49 of Set 7 | afaahiti
# Processing Record 0 of Set 8 | malayer
# Processing Record 1 of Set 8 | tateyama
# Processing Record 2 of Set 8 | pitimbu
# Processing Record 3 of Set 8 | alofi
# Processing Record 4 of Set 8 | bu'aale
# Processing Record 5 of Set 8 | kashary
# Processing Record 6 of Set 8 | mary
# Processing Record 7 of Set 8 | bibir hat
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | khovd
# Processing Record 10 of Set 8 | port macquarie
# Processing Record 11 of Set 8 | szczecinek
# Processing Record 12 of Set 8 | al-`ula
# City not found. Skipping...
# Processing Record 13 of Set 8 | walterboro
# Processing Record 14 of Set 8 | chamonix-mont-blanc
# Processing Record 15 of Set 8 | south bay
# Processing Record 16 of Set 8 | constantia
# Processing Record 17 of Set 8 | sur
# Processing Record 18 of Set 8 | cidreira
# Processing Record 19 of Set 8 | yuzhno-kurilsk
# Processing Record 20 of Set 8 | pointe aux piments
# Processing Record 21 of Set 8 | westport
# Processing Record 22 of Set 8 | tabou
# Processing Record 23 of Set 8 | new norfolk
# Processing Record 24 of Set 8 | san patricio
# Processing Record 25 of Set 8 | andergrove
# Processing Record 26 of Set 8 | quzhou
# Processing Record 27 of Set 8 | westhausen
# Processing Record 28 of Set 8 | bloemfontein
# Processing Record 29 of Set 8 | aykhal
# Processing Record 30 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 31 of Set 8 | carutapera
# Processing Record 32 of Set 8 | goundam
# Processing Record 33 of Set 8 | coyhaique
# Processing Record 34 of Set 8 | kiunga
# Processing Record 35 of Set 8 | canico
# Processing Record 36 of Set 8 | yurty
# Processing Record 37 of Set 8 | hilo
# Processing Record 38 of Set 8 | dubbo
# Processing Record 39 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 40 of Set 8 | alotau
# Processing Record 41 of Set 8 | saint-philippe
# Processing Record 42 of Set 8 | walvis bay
# Processing Record 43 of Set 8 | east london
# Processing Record 44 of Set 8 | sampit
# Processing Record 45 of Set 8 | perryton
# Processing Record 46 of Set 8 | santa terezinha
# Processing Record 47 of Set 8 | nagar karnul
# Processing Record 48 of Set 8 | stuarts draft
# Processing Record 49 of Set 8 | toamasina
# Processing Record 0 of Set 9 | steinbach
# Processing Record 1 of Set 9 | fandriana
# Processing Record 2 of Set 9 | klyuchi
# Processing Record 3 of Set 9 | pamandzi
# Processing Record 4 of Set 9 | kailua-kona
# Processing Record 5 of Set 9 | la'ie
# Processing Record 6 of Set 9 | san ramon
# Processing Record 7 of Set 9 | tallahassee
# Processing Record 8 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 9 of Set 9 | tefe
# Processing Record 10 of Set 9 | gardnerville ranchos
# Processing Record 11 of Set 9 | remire-montjoly
# Processing Record 12 of Set 9 | mount gambier
# Processing Record 13 of Set 9 | uzgen
# Processing Record 14 of Set 9 | nuuk
# Processing Record 15 of Set 9 | tanumah
# Processing Record 16 of Set 9 | karratha
# Processing Record 17 of Set 9 | chincha alta
# Processing Record 18 of Set 9 | kamaishi
# Processing Record 19 of Set 9 | malango
# Processing Record 20 of Set 9 | puerto rosario
# Processing Record 21 of Set 9 | kupang
# Processing Record 22 of Set 9 | mil'kovo
# Processing Record 23 of Set 9 | pandan
# Processing Record 24 of Set 9 | mpika
# Processing Record 25 of Set 9 | benjamin hill
# Processing Record 26 of Set 9 | visby
# Processing Record 27 of Set 9 | achinsk
# Processing Record 28 of Set 9 | kargasok
# Processing Record 29 of Set 9 | villa regina
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | skelleftea
# Processing Record 32 of Set 9 | tofol
# Processing Record 33 of Set 9 | paradera
# City not found. Skipping...
# Processing Record 34 of Set 9 | baiti
# Processing Record 35 of Set 9 | micheweni
# Processing Record 36 of Set 9 | shakhtersk
# Processing Record 37 of Set 9 | lacombe
# Processing Record 38 of Set 9 | zangguy
# City not found. Skipping...
# Processing Record 39 of Set 9 | labuan
# Processing Record 40 of Set 9 | vrangel'
# Processing Record 41 of Set 9 | san jose village
# City not found. Skipping...
# Processing Record 42 of Set 9 | nookat
# Processing Record 43 of Set 9 | balkanabat
# Processing Record 44 of Set 9 | kapa'a
# Processing Record 45 of Set 9 | williams lake
# Processing Record 46 of Set 9 | novaya igirma
# Processing Record 47 of Set 9 | bhag
# Processing Record 48 of Set 9 | ghat
# Processing Record 49 of Set 9 | kitui
# Processing Record 0 of Set 10 | ginir
# Processing Record 1 of Set 10 | hadibu
# Processing Record 2 of Set 10 | happy valley-goose bay
# Processing Record 3 of Set 10 | sao pedro do sul
# Processing Record 4 of Set 10 | jiuquan
# Processing Record 5 of Set 10 | punta del este
# Processing Record 6 of Set 10 | khanabad
# Processing Record 7 of Set 10 | acarau
# Processing Record 8 of Set 10 | lazaro cardenas
# Processing Record 9 of Set 10 | ugoofaaru
# Processing Record 10 of Set 10 | prado
# Processing Record 11 of Set 10 | ladario
# Processing Record 12 of Set 10 | stettler
# Processing Record 13 of Set 10 | mek'ele
# Processing Record 14 of Set 10 | singkil
# Processing Record 15 of Set 10 | vredenburg
# City not found. Skipping...
# Processing Record 16 of Set 10 | vallenar
# Processing Record 17 of Set 10 | carnarvon
# Processing Record 18 of Set 10 | ladismith
# City not found. Skipping...
# Processing Record 19 of Set 10 | baise city
# Processing Record 20 of Set 10 | edd
# Processing Record 21 of Set 10 | birjand
# Processing Record 22 of Set 10 | saint-francois
# Processing Record 23 of Set 10 | vila franca do campo
# Processing Record 24 of Set 10 | dolzhanskaya
# Processing Record 25 of Set 10 | manjeshvar
# Processing Record 26 of Set 10 | natchez
# Processing Record 27 of Set 10 | isla mujeres
# Processing Record 28 of Set 10 | la passe
# Processing Record 29 of Set 10 | iquique
# Processing Record 30 of Set 10 | tralee
# Processing Record 31 of Set 10 | jianshui
# Processing Record 32 of Set 10 | columbus
# Processing Record 33 of Set 10 | fuling
# Processing Record 34 of Set 10 | la foa
# Processing Record 35 of Set 10 | rio grande
# Processing Record 36 of Set 10 | bizerte
# Processing Record 37 of Set 10 | perg
# Processing Record 38 of Set 10 | dryden
# Processing Record 39 of Set 10 | petropavlovka
# Processing Record 40 of Set 10 | howard springs
# Processing Record 41 of Set 10 | colares
# Processing Record 42 of Set 10 | oamaru
# Processing Record 43 of Set 10 | lorengau
# Processing Record 44 of Set 10 | colonia
# Processing Record 45 of Set 10 | gamba
# Processing Record 46 of Set 10 | laayoune plage
# City not found. Skipping...
# Processing Record 47 of Set 10 | naduvannur
# Processing Record 48 of Set 10 | hithadhoo
# Processing Record 49 of Set 10 | bandeirantes
# Processing Record 0 of Set 11 | tazacorte
# Processing Record 1 of Set 11 | bechar
# Processing Record 2 of Set 11 | kulhudhuffushi
# Processing Record 3 of Set 11 | gamay
# Processing Record 4 of Set 11 | midvagur
# Processing Record 5 of Set 11 | kayangel
# Processing Record 6 of Set 11 | linqiong
# Processing Record 7 of Set 11 | guatire
# Processing Record 8 of Set 11 | sovetskaya gavan'
# Processing Record 9 of Set 11 | capo d'orlando
# Processing Record 10 of Set 11 | sumbe
# Processing Record 11 of Set 11 | arkhangel'sk
# Processing Record 12 of Set 11 | xam nua
# Processing Record 13 of Set 11 | hovd
# Processing Record 14 of Set 11 | chistyye bory
# Processing Record 15 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 16 of Set 11 | sorong
# Processing Record 17 of Set 11 | beau vallon
# Processing Record 18 of Set 11 | bayanhongor
# Processing Record 19 of Set 11 | wamba
# Processing Record 20 of Set 11 | al 'alamayn
# City not found. Skipping...
# Processing Record 21 of Set 11 | port arthur
# Processing Record 22 of Set 11 | the pas
# Processing Record 23 of Set 11 | mhamid
# Processing Record 24 of Set 11 | sinjai
# Processing Record 25 of Set 11 | gubat
# Processing Record 26 of Set 11 | abepura
# Processing Record 27 of Set 11 | kudahuvadhoo
# Processing Record 28 of Set 11 | el calafate
# Processing Record 29 of Set 11 | mitu
# Processing Record 30 of Set 11 | oodweyne
# Processing Record 31 of Set 11 | maunabo
# Processing Record 32 of Set 11 | temryuk
# Processing Record 33 of Set 11 | acapulco de juarez
# Processing Record 34 of Set 11 | mili
# Processing Record 35 of Set 11 | fale old settlement
# Processing Record 36 of Set 11 | singaparna
# Processing Record 37 of Set 11 | taman'
# Processing Record 38 of Set 11 | portland
# Processing Record 39 of Set 11 | akniste
# Processing Record 40 of Set 11 | nadym
# Processing Record 41 of Set 11 | melo
# Processing Record 42 of Set 11 | aljezur
# Processing Record 43 of Set 11 | chicoana
# Processing Record 44 of Set 11 | port-cartier
# Processing Record 45 of Set 11 | panchgani
# Processing Record 46 of Set 11 | lebanon
# Processing Record 47 of Set 11 | kundiawa
# Processing Record 48 of Set 11 | freetown
# Processing Record 49 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 0 of Set 12 | queimadas
# Processing Record 1 of Set 12 | alesund
# Processing Record 2 of Set 12 | neiafu
# Processing Record 3 of Set 12 | montepuez
# Processing Record 4 of Set 12 | manokwari
# Processing Record 5 of Set 12 | severobaykal'sk
# Processing Record 6 of Set 12 | ilha solteira
# Processing Record 7 of Set 12 | colipapa
# Processing Record 8 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 9 of Set 12 | obo
# Processing Record 10 of Set 12 | deniliquin
# Processing Record 11 of Set 12 | crucecita
# Processing Record 12 of Set 12 | weno
# Processing Record 13 of Set 12 | tarsus
# Processing Record 14 of Set 12 | yangor
# City not found. Skipping...
# Processing Record 15 of Set 12 | makassar
# Processing Record 16 of Set 12 | nova londrina
# Processing Record 17 of Set 12 | carolina beach
# Processing Record 18 of Set 12 | embu guacu
# Processing Record 19 of Set 12 | harstad
# Processing Record 20 of Set 12 | geraldton
# Processing Record 21 of Set 12 | angaur state
# Processing Record 22 of Set 12 | petoskey
# Processing Record 23 of Set 12 | xiongzhou
# Processing Record 24 of Set 12 | tshabong
# Processing Record 25 of Set 12 | kembe
# Processing Record 26 of Set 12 | howrah
# Processing Record 27 of Set 12 | port saint john's
# Processing Record 28 of Set 12 | crane
# Processing Record 29 of Set 12 | chokwe
# Processing Record 30 of Set 12 | khorugh
# Processing Record 31 of Set 12 | tamanrasset
# Processing Record 32 of Set 12 | hoi an
# Processing Record 33 of Set 12 | quellon
# Processing Record 34 of Set 12 | sao jose da coroa grande
# Processing Record 35 of Set 12 | satupa'itea
# City not found. Skipping...
# Processing Record 36 of Set 12 | bageshwar
# Processing Record 37 of Set 12 | bougouni
# Processing Record 38 of Set 12 | colonia menno
# Processing Record 39 of Set 12 | hailun
# Processing Record 40 of Set 12 | pitkyaranta
# Processing Record 41 of Set 12 | dumai
# Processing Record 42 of Set 12 | la rioja
# Processing Record 43 of Set 12 | quinhamel
# Processing Record 44 of Set 12 | prairie du chien
# Processing Record 45 of Set 12 | brandon
# Processing Record 46 of Set 12 | san rafael
# Processing Record 47 of Set 12 | grand island
# Processing Record 48 of Set 12 | talara
# Processing Record 49 of Set 12 | el alto
# Processing Record 0 of Set 13 | diamantino
# Processing Record 1 of Set 13 | rantoul
# Processing Record 2 of Set 13 | trairi
# Processing Record 3 of Set 13 | fort bragg
# Processing Record 4 of Set 13 | taman rajawali
# City not found. Skipping...
# Processing Record 5 of Set 13 | hammerfest
# Processing Record 6 of Set 13 | tibanbang
# Processing Record 7 of Set 13 | international falls
# Processing Record 8 of Set 13 | motueka
# Processing Record 9 of Set 13 | gadzhiyevo
# Processing Record 10 of Set 13 | chibougamau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -0.7393  -90.3518     22.45        65          12
# 1        bethel  41.3712  -73.4140     26.48        56           0
# 2     papatowai -46.5619  169.4708     14.22        73         100
# 3   olonkinbyen  70.9221   -8.7187     -2.39        82          14
# 4        puquio -14.7000  -74.1333     16.69        34          20
#
#    Wind Speed Country        Date
# 0        5.67      EC  1730922684
# 1        7.20      US  1730922685
# 2        0.55      NZ  1730922686
# 3       20.96      SJ  1730922688
# 4        7.74      PE  1730922689

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto ayora  -0.7393  -90.3518     22.45        65          12
# 1              bethel  41.3712  -73.4140     26.48        56           0
# 2           papatowai -46.5619  169.4708     14.22        73         100
# 3         olonkinbyen  70.9221   -8.7187     -2.39        82          14
# 4              puquio -14.7000  -74.1333     16.69        34          20
#
#          Wind Speed Country        Date
# City_ID
# 0              5.67      EC  1730922684
# 1              7.20      US  1730922685
# 2              0.55      NZ  1730922686
# 3             20.96      SJ  1730922688
# 4              7.74      PE  1730922689

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], alpha=.75, edgecolors='black')

current_date = datetime.date.today()

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Max Temperature - {current_date}") 
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Humidity - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Cloudiness - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], alpha=.75, edgecolors='black')

# Incorporate the other graph properties
plt.title(f"City Latitude vs. Wind Speed - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# Define a function to create Linear Regression plots
def linreg_plot(x,y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    f, ax = plt.subplots()
    ax.scatter(x,y)
    ax.plot(x, regress_values, 'red')
    
    return ax, line_eq, rvalue
    
ax, line_eq, rvalue =linreg_plot(city_data_df['Lat'], city_data_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(-30,12),fontsize=15,color="red")
plt.title(f"City Latitude vs. Wind Speed - {current_date}")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.07531352915326772

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                  bethel  41.3712 -73.4140     26.48        56           0
# 3             olonkinbyen  70.9221  -8.7187     -2.39        82          14
# 8              st. john's  47.5649 -52.7093     10.54        95         100
# 10                 chinde  26.8212  87.7095     18.91        68           0
# 12       arkhipo-osipovka  44.3700  38.5200     10.44        71          95
#
#          Wind Speed Country        Date
# City_ID
# 1              7.20      US  1730922685
# 3             20.96      SJ  1730922688
# 8              7.20      CA  1730922609
# 10             3.07      NP  1730922695
# 12             4.93      RU  1730922681

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']<=0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          puerto ayora  -0.7393  -90.3518     22.45        65          12
# 2             papatowai -46.5619  169.4708     14.22        73         100
# 4                puquio -14.7000  -74.1333     16.69        34          20
# 5             grytviken -54.2811  -36.5092      1.16        56          86
# 6        port elizabeth -33.9180   25.5701     13.51        87          40
#
#          Wind Speed Country        Date
# City_ID
# 0              5.67      EC  1730922684
# 2              0.55      NZ  1730922686
# 4              7.74      PE  1730922689
# 5              1.79      GS  1730922690
# 6              1.03      ZA  1730922691

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df["Lat"], northern_hemi_df["Max Temp"])
ax.plot()
plt.annotate(line_eq,(10,-20),fontsize=15,color="red")
plt.title("Latitude vs. Max Temp, Northern Hemisphere")
plt.xlabel('Latitude')
plt.ylabel('Temp (C)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: -0.8274120620859209

# %%
# Linear regression on Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'])
ax.plot()
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
plt.title('Latitude vs. Max Temp, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Temp (C)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.6998929774341386

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and temperature is much stronger in the northern than southern hemishpere, as seen in the tightness of the scatterplot points and will as the R squared values. However the trend is the same for both; the further from the equator, the colder the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Humidity'])
ax.plot()
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.title('Latitude vs. Humidity, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.2934956050835822

# %%
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Humidity'])
ax.plot()
plt.annotate(line_eq,(-50,50),fontsize=15,color="red")
plt.title('City Latitude vs. Humidity, southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.24403180466691043

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and humidity appears stronger in the northern hemisphere based on the R value, but I'm not convinenced a linear regression is the best way to model this. I think using a 2nd order polynomial would be better if not trying a nonparametric regression.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'])
ax.plot()
plt.annotate(line_eq,(50,15),fontsize=15,color="red")
plt.title('Latitude vs. Cloudiness, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloundiness (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.2870003388338522

# %%
# Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'])
ax.plot()
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")
plt.title('City Latitude vs. Cloudiness, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Cloundiness (%)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.13634051058194796

# %% [markdown]
# **Discussion about the linear relationship:** The relationship between latitude and cloud cover is not very strong, but it is surprisingly similar for both hemishperes. The regressions indicate a one degree latitude change is related to roughly 0.5% change in cloud cover on average.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
ax, line_eq, rvalue =linreg_plot(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(5,12),fontsize=15,color="red")
plt.title('City Latitude vs. Wind Spped, Northern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: 0.1443267248508013

# %%
# Southern Hemisphere
ax, line_eq, rvalue =linreg_plot(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'])
ax.plot()
plt.annotate(line_eq,(-50,12),fontsize=15,color="red")
plt.title('City Latitude vs. Wind Spped, Southern Hemisphere')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f"R-value: {rvalue}")
# Out:
# R-value: -0.05914135312393157

# %% [markdown]
# **Discussion about the linear relationship:** There is essentially no (linear) relationship between latitude and wind speed. For both hemisphere the slope coefficients and r-values are near zero.
